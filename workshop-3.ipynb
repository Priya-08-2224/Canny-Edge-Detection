# %% [markdown]
# ## Workshop 3
# ## Name : Priyadharshini J
# ## Reg no: 212224230210

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('Emerald_Lakes_New_Zealand.jpg')

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
edges = cv2.Canny(blur, 100, 200)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')
plt.show()

# %%
plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(4271.5), np.float64(2847.5), np.float64(-0.5))

# %%
plt.show()

# %%
edges_low = cv2.Canny(blur, 50, 100)
edges_high = cv2.Canny(blur, 150, 300)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(edges_low, cmap='gray')
plt.title("Low Threshold")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(edges_high, cmap='gray')
plt.title("High Threshold")
plt.axis('off')

plt.show()
